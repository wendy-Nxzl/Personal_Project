# %%
import pandas as pd
df = pd.read_csv('New_AAPL.csv')
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     1980-12-12   0.128348   0.128906   0.128348   0.128348   0.100323
# 1     1980-12-15   0.122210   0.122210   0.121652   0.121652   0.095089
# 2     1980-12-16   0.113281   0.113281   0.112723   0.112723   0.088110
# 3     1980-12-17   0.115513   0.116071   0.115513   0.115513   0.090291
# 4     1980-12-18   0.118862   0.119420   0.118862   0.118862   0.092908
# ...          ...        ...        ...        ...        ...        ...
# 9106  2017-01-25  30.105000  30.525000  30.070000  30.469999  28.644361
# 9107  2017-01-26  30.417500  30.610001  30.400000  30.485001  28.658466
# 9108  2017-01-27  30.535000  30.587500  30.400000  30.487499  28.660812
# 9109  2017-01-30  30.232500  30.407499  30.165001  30.407499  28.585606
# 9110  2017-01-31  30.287500  30.347500  30.155001  30.337500  28.519794
#
#          Volume
# 0     469033600
# 1     175884800
# 2     105728000
# 3      86441600
# ...

# %%
df.std()
# Out:
# <ipython-input-3-ce97bb7eaef8>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# Open         8.287116e+00
# High         8.358116e+00
# Low          8.209437e+00
# Close        8.284931e+00
# Adj Close    7.477804e+00
# Volume       3.518442e+08
# dtype: float64

# %%
df['Close'].std()
# Out:
# 8.284931079692324

# %%
df['Close'].mean()
# Out:
# 4.64104055866535

# %%
def get_df_from_csv(filename):
  df = pd.read_csv(filename)
  return df

stock = "New_AAPL"
df= get_df_from_csv('{}.csv'.format(stock))
print("Stock: {} \n\n- Mean\t\t\t: {} \n- Standard deviation\t: {}".format(stock, df['Close'].mean(), df['Close'].std()))
# Out:
# Stock: New_AAPL
#
# - Mean			: 4.64104055866535
# - Standard deviation	: 8.284931079692324

# %%
def get_df_from_csv(filename):
  df = pd.read_csv(filename)
  return df

def get_stats(stock):
  df = get_df_from_csv('{}.csv'.format(stock))
  mean = df['Close'].mean()
  std = df['Close'].std()
  cov = std / mean
  return round(mean, 5), round(std, 5), round(cov, 5)
  
stock = "New_AAPL"
stats = get_stats(stock)
print("Stock: {} \n\n- Mean\t\t\t\t: {} \n- Standard deviation\t\t: {} \n- Coefficient of variation\t: {}".format(stock, stats[0], stats[1], stats [2]))
# Out:
# Stock: New_AAPL
#
# - Mean				: 4.64104
# - Standard deviation		: 8.28493
# - Coefficient of variation	: 1.78515

# %%
import matplotlib.pyplot as plt

data = df['Close']
mean = df['Close'].mean()
std = df['Close'].std()
min_value = min(data)
max_value = max(data)

plt.title("AAPL Dataset")
plt.ylim(min_value - 100, max_value + 100)
plt.scatter(x=df.index, y=df['Close'])
plt.hlines(y=mean, xmin = 0, xmax = len(data))
plt.hlines(y=mean - std, xmin = 0, xmax = len(data), colors = 'r')
plt.hlines(y=mean + std, xmin = 0, xmax = len(data), colors = 'r')
plt.hlines(y=mean - 2*std, xmin = 0, xmax = len(data), colors = 'g')
plt.hlines(y=mean + 2*std, xmin = 0, xmax = len(data), colors = 'g')
plt.show()
